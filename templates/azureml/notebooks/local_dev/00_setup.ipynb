# %% [markdown]
# ## Production Time Prediction ML Project

# %% [markdown]
# ###### **NOTE**: If you use mlflow in windows environment (especially in jupyter notebook), and run UI with Makefile commands in WSL, you need make sure that mlflow is installed in both environments (windows and WSL) and use the same version. Otherwise, you may encounter errors when trying to run the UI or log experiments.

# %%
# %pip install \
    azure-identity==1.17.0 \
    azure-storage-blob==12.28.0 \
    duckdb==1.4.1 \
    scikit-learn==1.8.0 \
    skops==0.14.0 \
    fast-hdbscan==0.3.2 \
    xgboost==3.2.0 \
    pandas==2.3.3 \
    matplotlib==3.10.8 \
    seaborn==0.13.2 \
    plotly==6.6.0 \
    mlflow==3.10.1 \
    optuna==4.8.0 \
    shap==0.51.0 \
    python-dotenv --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ---
# ---
